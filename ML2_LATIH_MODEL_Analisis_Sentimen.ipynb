# %% [markdown]
# #### Mengimport library pandas untuk membaca file csv

# %%
import pandas as pd

# %% [markdown]
# *   Membaca file csv yang sebelumnya sudah diunduh dari kode scrapping
# *   Mengetahui jumlah kolom dan jumlah ulasan pada file df/csv

# %%
app_reviews_df = pd.read_csv("/content/review_jkn_mobile_app.csv")

jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
print(jumlah_ulasan)
print(jumlah_kolom)
# Out:
# 9999
# 1

# %%
app_reviews_df
# Out:
#      Fitu Face Recognition Belum Sempurna Gagal Terus. Padahal udah di rs dan waktunya kontrol 🥺, gara-gara update ini ganbisa lanjut ke rs, pas checkin gabisa di skip apa harus wajib face recognition padahal, ada opsi skip dulu baru bisa lanjut, gimana sih, harusnya make sure bisa di implement !!!!
# 0     Aplikasi apaan ini, banyakan errornya, mau amb...
# 1     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 2     setelah diupdate malah makin bugs, masa tiap b...
# 3     Saat melakukan pendaftaran, tidak kunjung mend...
# 4     Tadinya bintang 5 turun ke bintang 3...harus v...
# ...                                                 ...
# 9994  Sudah update ke versi 36.1 masih aja tetap bil...
# 9995  Di updat malah ga bisa di buka aneh program pe...
# 9996  Merubah faskes tingkat 1 melalui aplikasi sela...
# 9997  Nyesel banget melakukan pembaruan. Mau cek kar...
# 9998  Mau minta warga partisipasi ikut program bpjs ...
#
# [9999 rows x 1 columns]

# %% [markdown]
# #### Mengetahui info df

# %%
app_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                   --------------  -----
# ...

# %%
app_reviews_df.dtypes
# Out:
# Fitu Face Recognition Belum Sempurna Gagal Terus. Padahal udah di rs dan waktunya kontrol 🥺, gara-gara update ini ganbisa lanjut ke rs, pas checkin gabisa di skip apa harus wajib face recognition padahal, ada opsi skip dulu baru bisa lanjut, gimana sih, harusnya make sure bisa di implement !!!!    object
# dtype: object

# %%
jkn_df = pd.read_csv("/content/review_jkn_mobile_app.csv", header=None, names=["Review"])
jkn_df
# Out:
#                                                  Review
# 0     Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1     Aplikasi apaan ini, banyakan errornya, mau amb...
# 2     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3     setelah diupdate malah makin bugs, masa tiap b...
# 4     Saat melakukan pendaftaran, tidak kunjung mend...
# ...                                                 ...
# 9995  Sudah update ke versi 36.1 masih aja tetap bil...
# 9996  Di updat malah ga bisa di buka aneh program pe...
# 9997  Merubah faskes tingkat 1 melalui aplikasi sela...
# 9998  Nyesel banget melakukan pembaruan. Mau cek kar...
# 9999  Mau minta warga partisipasi ikut program bpjs ...
#
# [10000 rows x 1 columns]

# %%
jkn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  10000 non-null  object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %% [markdown]
# #### Melakukan pembersihan: menghapus nilai yang kosong/null values

# %%
jkn_df = jkn_df.dropna()
jkn_df
# Out:
#                                                  Review
# 0     Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1     Aplikasi apaan ini, banyakan errornya, mau amb...
# 2     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3     setelah diupdate malah makin bugs, masa tiap b...
# 4     Saat melakukan pendaftaran, tidak kunjung mend...
# ...                                                 ...
# 9995  Sudah update ke versi 36.1 masih aja tetap bil...
# 9996  Di updat malah ga bisa di buka aneh program pe...
# 9997  Merubah faskes tingkat 1 melalui aplikasi sela...
# 9998  Nyesel banget melakukan pembaruan. Mau cek kar...
# 9999  Mau minta warga partisipasi ikut program bpjs ...
#
# [10000 rows x 1 columns]

# %% [markdown]
# #### Melakukan pembersihan: menghapus nilai yang terduplikasi

# %%
jkn_df = jkn_df.drop_duplicates()
jkn_df
# Out:
#                                                  Review
# 0     Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1     Aplikasi apaan ini, banyakan errornya, mau amb...
# 2     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3     setelah diupdate malah makin bugs, masa tiap b...
# 4     Saat melakukan pendaftaran, tidak kunjung mend...
# ...                                                 ...
# 9995  Sudah update ke versi 36.1 masih aja tetap bil...
# 9996  Di updat malah ga bisa di buka aneh program pe...
# 9997  Merubah faskes tingkat 1 melalui aplikasi sela...
# 9998  Nyesel banget melakukan pembaruan. Mau cek kar...
# 9999  Mau minta warga partisipasi ikut program bpjs ...
#
# [10000 rows x 1 columns]

# %% [markdown]
# #### Melihat info df lagi, terdapat perubahan jumlah data pada df setelah dilakukan pembersihan

# %%
jkn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  10000 non-null  object
# dtypes: object(1)
# memory usage: 78.2+ KB

# %% [markdown]
# ### Mengimport library dan modul yang dibutuhkan

# %%
import datetime as dt
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# !pip install sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

from wordcloud import WordCloud

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Pre-processing text: membuat beberapa fungsi untuk memfilter teks

# %%
def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#[A-Za-z0-9]+', '', text)
    text = re.sub(r'RT[\s]', '', text)
    text = re.sub(r"http\S+", '', text)
    text = re.sub(r'[0-9]+', '', text)
    text = re.sub(r'[^\w\s]', '', text)

    text = text.replace('\n', ' ')
    text = text.translate(str.maketrans('', '', string.punctuation))
    text = text.strip(' ')
    return text

def casefoldingText(text):
    text = text.lower()
    return text

def tokenizingText(text):
    text = word_tokenize(text)
    return text

def filteringText(text):
    listStopwords = set(stopwords.words('indonesian'))
    listStopwords1 = set(stopwords.words('english'))
    listStopwords.update(listStopwords1)
    listStopwords.update(['iya','yaa','ya','gak','ga','gaa','nya','na','sih','ku',"di","ya","loh","kah","kh","woi","woii","woy", "wkwk"])
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered
    return text

def stemmingText(text):
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    words = text.split()
    stemmed_words = [stemmer.stem(word) for word in words]
    stemmed_text = ' '.join(stemmed_words)
    return stemmed_text

def toSentence(list_words):
    sentence = ' '.join(word for word in list_words)
    return sentence

# %% [markdown]
# #### Tokenization: membuat kata baku atau pembenaran dari slangwords (bahasa gaul)

# %%
slangwords = {
    "@": "di", "abis": "habis", "masi": "masih", "bgt": "banget", "maks": "maksimal", "plisss": "tolong", "indo": "indonesia", "ad": "ada", "plis": "tolong", "pls": "tolong", "cod": "bayar di tempat",
    "adlh": "adalah", "afaik": "as far as i know", "ahaha": "haha", "aj": "saja", "ak": "saya", "alay": "norak", "ambilin": "ambilkan", "ancur": "hancur", "anjrit": "anjing", "anter": "antar",
    "ap2": "apa-apa", "apasih": "apa sih", "apes": "sial", "aps": "apa", "aq": "saya", "ato": "atau", "au ah": "tidak mau tahu", "ay": "sayang", "ayank": "sayang", "bakalan": "akan", "bandes": "bantuan desa",
    "basbang": "basi", "bcanda": "bercanda", "bdg": "bandung", "begajulan": "nakal", "beliin": "belikan", "bentar": "sebentar", "beresin": "membereskan", "bete": "bosan", "bg": "abang", "bgmn": "bagaimana",
    "bintal": "bimbingan mental", "bkl": "akan", "bknnya": "bukannya", "blegug": "bodoh", "blh": "boleh", "bln": "bulan", "blum": "belum", "bnci": "benci", "bnran": "yang benar", "boker": "buang air besar",
    "br": "baru", "brg": "bareng", "bro": "saudara laki-laki", "bru": "baru", "bs": "bisa", "bsen": "bosan", "bt": "buat", "btw": "ngomong-ngomong", "bumil": "ibu hamil", "bw": "bawa", "bwt": "buat", "byk": "banyak",
    "cengengesan": "tertawa", "cepet": "cepat", "ckepp": "cakep", "ckp": "cakep", "cmiiw": "correct me if i'm wrong", "cmpur": "campur", "cpe": "capek", "d": "di", "dah": "deh", "dapet": "dapat", "dek": "adik", "demen": "suka",
    "dgn": "dengan", "dimintak": "diminta","disono": "di sana", "dket": "dekat", "dkk": "dan kawan-kawan", "dll": "dan lain-lain", "dlu": "dulu", "dngn": "dengan", "dodol": "bodoh", "dongs": "dong", "dpt": "dapat", "dri": "dari",
    "drmn": "darimana", "drtd": "dari tadi", "dst": "dan seterusnya", "dtg": "datang", "duh": "aduh", "emng": "memang", "endak": "tidak", "enggak": "tidak", "gaje": "tidak jelas", "gak papa": "tidak apa-apa", "gaptek": "gagap teknologi",
    "gatek": "gagap teknologi", "gawe": "kerja", "gbs": "tidak bisa", "gebetan": "orang yang disuka", "geje": "tidak jelas", "gile": "gila", "gimana": "bagaimana", "gj": "tidak jelas", "gmana": "bagaimana", "goblok": "bodoh", "gpny": "tidak punya",
    "gtau": "tidak tahu", "gua": "saya", "guoblok": "goblok", "gw": "saya", "haha": "tertawa", "hlm": "halaman", "hny": "hanya", "hr": "hari", "hrus": "harus", "huff": "mengeluh", "ilang": "hilang", "iye": "iya", "ja": "saja", "jadiin": "jadi",
    "jdi": "jadi", "jga": "juga", "jgnkan": "jangankan", "jir": "anjing", "jln": "jalan", "jutek": "galak", "k": "ke", "kab": "kabupaten", "kalo": "kalau", "kampret": "sialan", "kanwil": "kantor wilayah", "karna": "karena", "kbr": "kabar", "kdu": "harus",
    "kec": "kecamatan", "kel": "kelurahan", "kemaren": "kemarin", "kepengen": "mau", "kepingin": "mau", "ketrima": "diterima", "kl": "kalau", "klw": "kalau", "km": "kamu", "kmrn": "kemarin", "krm": "kirim", "ktmu": "ketemu", "ktr": "kantor", "kyk": "seperti",
    "la": "lah", "lelet": "lambat", "lemot": "lambat", "lgi": "lagi", "lgsg": "langsung", "liat": "lihat", "lp": "lupa", "org": "orang", "lum": "belum", "luthu": "lucu", "lwn": "lawan", "maacih": "terima kasih", "macem": "macam", "macih": "masih",
    "magabut": "makan gaji buta", "maksain": "memaksa", "mepet": "dekat sekali", "mgu": "minggu", "problem": "masalah", "tahi": "kotoran", "tilep": "tilap", "happy": "bahagia", "tak": "tidak", "makasi": "terima kasih", "mnolak": "tolak",
    "trending": "trend", "taik": "tahi", "wkwkkw": "tertawa", "benarjujur": "jujur", "mgkin": "mungkin", "app": "aplikasi", "sat set": "cepat", "bpj": "bpjs", "kls": "kelas", "gk": "tidak", "kelinik": "klinik", "nakes": "tenaga kesehatan"
}

def fix_slangwords(text):
    words = text.split()
    fixed_words = []

    for word in words:
        if word.lower() in slangwords:
            fixed_words.append(slangwords[word.lower()])
        else:
            fixed_words.append(word)

    fixed_text = ' '.join(fixed_words)
    return fixed_text

# %% [markdown]
# #### Mengecek nama kolom sebelum menjalankan fungsi

# %%
print(jkn_df.columns)
# Out:
# Index(['Review'], dtype='object')

# %%
jkn_df.head()
# Out:
#                                               Review
# 0  Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1  Aplikasi apaan ini, banyakan errornya, mau amb...
# 2  Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3  setelah diupdate malah makin bugs, masa tiap b...
# 4  Saat melakukan pendaftaran, tidak kunjung mend...

# %% [markdown]
# #### Menjalankan fungsi-fungsi yang telah dibuat sebelumnya

# %%
jkn_df['text_clean'] = jkn_df['Review'].apply(cleaningText)

jkn_df['text_casefoldingText'] = jkn_df['text_clean'].apply(casefoldingText)

jkn_df['text_slangwords'] = jkn_df['text_casefoldingText'].apply(fix_slangwords)

jkn_df['text_tokenizingText'] = jkn_df['text_slangwords'].apply(tokenizingText)

jkn_df['text_stopword'] = jkn_df['text_tokenizingText'].apply(filteringText)

jkn_df['text_akhir'] = jkn_df['text_stopword'].apply(toSentence)

# %%
jkn_df
# Out:
#                                                  Review  \
# 0     Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1     Aplikasi apaan ini, banyakan errornya, mau amb...
# 2     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3     setelah diupdate malah makin bugs, masa tiap b...
# 4     Saat melakukan pendaftaran, tidak kunjung mend...
# ...                                                 ...
# 9995  Sudah update ke versi 36.1 masih aja tetap bil...
# 9996  Di updat malah ga bisa di buka aneh program pe...
# 9997  Merubah faskes tingkat 1 melalui aplikasi sela...
# 9998  Nyesel banget melakukan pembaruan. Mau cek kar...
# 9999  Mau minta warga partisipasi ikut program bpjs ...
#
#                                              text_clean  \
# 0     Fitu Face Recognition Belum Sempurna Gagal Ter...
# 1     Aplikasi apaan ini banyakan errornya mau ambil...
# 2     Aplikasi ny tidak bisa verifikasi wajah nyesel...
# 3     setelah diupdate malah makin bugs masa tiap bu...
# ...

# %% [markdown]
# ### Pelabelan: Mengimport kamus kata-kata positif dan negatif dari github

# %%
import csv
import requests
from io import StringIO

lexicon_positive = dict()

response = requests.get('https://raw.githubusercontent.com/angelmetanosaa/dataset/main/lexicon_positive.csv')

if response.status_code == 200:
    reader = csv.reader(StringIO(response.text), delimiter=',')
    for row in reader:
        lexicon_positive[row[0]] = int(row[1])
else:
    print("Failed to fetch positive lexicon data")


lexicon_negative = dict()

response = requests.get('https://raw.githubusercontent.com/angelmetanosaa/dataset/main/lexicon_negative.csv')

if response.status_code == 200:
    reader = csv.reader(StringIO(response.text), delimiter=',')
    for row in reader:
        lexicon_negative[row[0]] = int(row[1])
else:
    print("Failed to fetch negative lexicon data")

# %% [markdown]
# #### Pelabelan: Membuat fungsi untuk menentukan skor dalam kata positif, negatif, dan netral sesuai kamus yang sudah didapat

# %%
def sentiment_analysis_lexicon_indonesia(text):
    score = 0

    for word in text:
        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
        if (word in lexicon_negative):
            score = score + lexicon_negative[word]

    polarity=''

    if (score > 0):
      polarity = 'positive'
    elif (score < 0):
      polarity = 'negative'
    else:
      polarity = 'neutral'

    return score, polarity

# %% [markdown]
# #### Pelabelan: Hasil dari pelabelan

# %%
results = jkn_df['text_stopword'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
jkn_df['polarity_score'] = results[0]
jkn_df['polarity'] = results[1]
print(jkn_df['polarity'].value_counts())
# Out:
# polarity
# negative    7942
# positive    1647
# neutral      411
# Name: count, dtype: int64

# %% [markdown]
# ### Melakukan visualisasi analisis sentimen dari hasil pelabelan data

# %%
import matplotlib.pyplot as plt

sizes = [count for count in jkn_df['polarity'].value_counts()]
labels = list(jkn_df['polarity'].value_counts().index)
explode = [0.1 if label == 'positive' else 0 for label in labels]
colors = ['#FC8D62', '#66C2A5', '#8DA0CB']

fig, ax = plt.subplots(figsize=(6, 6))
ax.pie(x=sizes, labels=labels, autopct='%1.2f%%', explode=explode, textprops={'fontsize': 14}, colors=colors)

ax.set_title('Polaritas Analisis Sentimen dalam Review Aplikasi JKN Mobile', fontsize=16, pad=20)
plt.show()

# %% [markdown]
# #### Membuat tweets positif dan negatif untuk visulisasi

# %%
pd.set_option('display.max_colwidth', 3000)

positive_tweets = jkn_df[jkn_df['polarity'] == 'positive']
positive_tweets = positive_tweets[['text_akhir', 'polarity_score', 'polarity','text_stopword']]
positive_tweets = positive_tweets.sort_values(by='polarity_score', ascending=False)
positive_tweets = positive_tweets.reset_index(drop=True)
positive_tweets.index += 1

# %%
pd.set_option('display.max_colwidth', 3000)

negative_tweets = jkn_df[jkn_df['polarity'] == 'negative']
negative_tweets = negative_tweets[['text_akhir', 'polarity_score', 'polarity','text_stopword']]
negative_tweets = negative_tweets.sort_values(by='polarity_score', ascending=True)
negative_tweets = negative_tweets[0:10]
negative_tweets = negative_tweets.reset_index(drop=True)
negative_tweets.index += 1

# %%
pd.set_option('display.max_colwidth', 3000)

neutral_tweets = jkn_df[jkn_df['polarity'] == 'neutral']
neutral_tweets = neutral_tweets[['text_akhir', 'polarity_score', 'polarity','text_stopword']]
neutral_tweets = neutral_tweets.sort_values(by='polarity_score', ascending=True)
neutral_tweets = neutral_tweets[0:10]
neutral_tweets = neutral_tweets.reset_index(drop=True)
neutral_tweets.index += 1

# %% [markdown]
# #### Memvisulisasi: wordcloud kata positif dan negatif

# %%
list_words = ''

for tweet in jkn_df['text_stopword']:
    for word in tweet:
        list_words += ' ' + (word)

wordcloud = WordCloud(
    width=600,
    height=400,
    background_color='white',
    min_font_size=10,
    colormap='coolwarm'
).generate(list_words)

fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title('Word Cloud of JKN Mobile App Reviews Data', fontsize=18)
ax.grid(False)
ax.imshow((wordcloud))
ax.axis('off')

fig.tight_layout(pad=0)
plt.show()

# %% [markdown]
# #### Memvisulisasi: wordcloud kata negatif

# %%
list_words = ''

for tweet in negative_tweets['text_stopword']:
    for word in tweet:
        list_words += ' ' + (word)

wordcloud = WordCloud(
    width=600,
    height=400,
    background_color='white',
    min_font_size=10,
    colormap='coolwarm'
).generate(list_words)

fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title('Word Cloud of Negative JKN Mobile App Reviews Data', fontsize=18)
ax.grid(False)
ax.imshow((wordcloud))
ax.axis('off')

fig.tight_layout(pad=0)
plt.show()

# %%
print(negative_tweets[['text_akhir', 'polarity_score']])
# Out:
#                                                                                                                                                                                                                                                                                                                                    text_akhir  \
# 1                               aplikasi sampah daftar aja dipersulit kode otp udah masuk pulsa udah habis aplikasi status gagal masukin kode otp klo status aplikasi gagal mengirim kode otp kode otp udah masuk tp status masukin kode otp status gagal pengen kode otp tuh pake pulsa udah dicoba puluhan kali gagal pulsa kepotong maling
# ...

# %% [markdown]
# #### Memvisulisasi: wordcloud kata positif

# %%
list_words = ''

for tweet in positive_tweets['text_stopword']:
    for word in tweet:
        list_words += ' ' + (word)

wordcloud = WordCloud(
    width=600,
    height=400,
    background_color='white',
    min_font_size=10,
    colormap='coolwarm'
).generate(list_words)

fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title('Word Cloud of Positive JKN Mobile App Reviews Data', fontsize=18)
ax.grid(False)
ax.imshow((wordcloud))
ax.axis('off')

fig.tight_layout(pad=0)
plt.show()

# %%
print(positive_tweets[['text_akhir', 'polarity_score']])
# Out:
#                                                                                                                                                                                                                                                                                                  text_akhir  \
# 1                                                                           seneng dateng bpjs pusat yg didaerah jakarta utara plumpang pelayanan security cs fl ramah ruangannya bersih wangi doang min mohon disediakan ngecharge hp yah pas hp lobet nunggu antrian enaknya main hp hehe terimakasih min
# 2                             iuran kualitas pelayanan diperbaiki mobile ubah faskes tingkat pilihan faskes kota muncul aplikasinya yg mempermudah terkendala tolong diperbaiki dipermudah pengaduan sperti dilayani live chat jam jaman modern via telpon iuran dibarengi peningkatan kualitas terimakasih
# ...

# %% [markdown]
# #### Memvisulisasi: wordcloud kata netral

# %%
list_words = ''

for tweet in neutral_tweets['text_stopword']:
    for word in tweet:
        list_words += ' ' + (word)

wordcloud = WordCloud(
    width=600,
    height=400,
    background_color='white',
    min_font_size=10,
    colormap='coolwarm'
).generate(list_words)


fig, ax = plt.subplots(figsize=(8, 6))

ax.set_title('Word Cloud of Neutral JKN Mobile App Reviews Data', fontsize=18)
ax.grid(False)
ax.imshow((wordcloud))
ax.axis('off')

fig.tight_layout(pad=0)
plt.show()

# %%
print(neutral_tweets[['text_akhir', 'polarity_score']])
# Out:
#                                                                                                                                                                                                                                                            text_akhir  \
# 1   desain aplikasinya bagus sistemnya jelek banget pas pendaftaran akun registrasi nomor hp sesuailah kode otpnya terkirim wkwkwk niatnya bantu cepat antrian online mempersulit bikin habis pulsa aja wkwkwk dimohon tingkatkan sistemnya admin aplikasi pemerintah
# 2                                                                                     mohon ditindaklanjuti developer mobile jknpendaftar login mendaftar autodebit berputar disitu mengakses menu utama fitur dibutuhkan loginkembali menu utama alhasil login ulang
# ...

# %% [markdown]
# #### Memvisualisasi: Distribusi kelas kata, kata yang sering muncul, dan distribusi panjang teks

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))

class_dist_plot = sns.countplot(x='polarity', data=jkn_df)
plt.title('Distribusi Kategori Kelas')

for p in class_dist_plot.patches:
    class_dist_plot.annotate(format(p.get_height(), '.0f'),
                              (p.get_x() + p.get_width() / 2., p.get_height()),
                              ha='center', va='center',
                              xytext=(0, 10),
                              textcoords='offset points')

plt.show()

plt.figure(figsize=(10, 6))

jkn_df['text_length'] = jkn_df['text_akhir'].apply(lambda x: len(x.split()))
sns.histplot(jkn_df['text_length'])
plt.title('Distribusi Panjang Teks')
plt.show()

plt.figure(figsize=(12, 6))

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(jkn_df['text_akhir'])
tfidf_df = pd.DataFrame(X.toarray(), columns=vectorizer.get_feature_names_out())
tfidf_df = tfidf_df.sum().reset_index(name='jumlah')
tfidf_df = tfidf_df.sort_values('jumlah', ascending=False).head(20)
sns.barplot(x='jumlah', y='index', data=tfidf_df)
plt.title('Kata yang Paling Sering Muncul')
plt.show()

# %% [markdown]
# ### Data splitting dengan tf-idf

# %%
import pandas as pd

# %% [markdown]
# #### membagi dataframe mnejadi fitur dan label

# %%
X = jkn_df['text_akhir']
y = jkn_df['polarity']

# %% [markdown]
# #### mengekstraksi fitur dg tf-idf

# %%
tfidf = TfidfVectorizer(max_features=200, min_df=17, max_df=0.8 )
X_tfidf = tfidf.fit_transform(X)

# %% [markdown]
# #### mengkonversi hasil menjadi df dan melihat hasilnya

# %%
ekstrak_df = pd.DataFrame(X_tfidf.toarray(), columns=tfidf.get_feature_names_out())
ekstrak_df
# Out:
#            aja     akses  aktif  akun      aneh   antrian  apk  aplikasi  \
# 0     0.000000  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.000000
# 1     0.000000  0.000000    0.0   0.0  0.000000  0.396179  0.0  0.300021
# 2     0.251654  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.157553
# 3     0.000000  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.144750
# 4     0.000000  0.313943    0.0   0.0  0.000000  0.000000  0.0  0.116816
# ...        ...       ...    ...   ...       ...       ...  ...       ...
# 9995  0.237081  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.000000
# 9996  0.000000  0.000000    0.0   0.0  0.700616  0.000000  0.0  0.000000
# 9997  0.000000  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.139424
# 9998  0.000000  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.000000
# 9999  0.000000  0.000000    0.0   0.0  0.000000  0.000000  0.0  0.176592
#
#       aplikasinya      auto  ...  ulang    update  upgrade       utk  \
# ...

# %% [markdown]
# #### Membagi data menjadi data train (30%) dan data test (70%)

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Pemodelan: melihat keakurasian dari data train dan data tes

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Pemodelan: Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Membuat objek model Random Forest
random_forest = RandomForestClassifier()

# Melatih model Random Forest pada data pelatihan
random_forest.fit(X_train.toarray(), y_train)

# Prediksi sentimen pada data pelatihan dan data uji
y_pred_train_rf = random_forest.predict(X_train.toarray())
y_pred_test_rf = random_forest.predict(X_test.toarray())

# Evaluasi akurasi model Random Forest
accuracy_train_rf = accuracy_score(y_pred_train_rf, y_train)
accuracy_test_rf = accuracy_score(y_pred_test_rf, y_test)

# Menampilkan akurasi
print('Random Forest - accuracy_train:', accuracy_train_rf)
print('Random Forest - accuracy_test:', accuracy_test_rf)
# Out:
# Random Forest - accuracy_train: 0.9985714285714286
# Random Forest - accuracy_test: 0.8343333333333334

# %% [markdown]
# ### Pemodelan: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# Membuat objek model Logistic Regression
logistic_regression = LogisticRegression()

# Melatih model Logistic Regression pada data pelatihan
logistic_regression.fit(X_train.toarray(), y_train)

# Prediksi sentimen pada data pelatihan dan data uji
y_pred_train_lr = logistic_regression.predict(X_train.toarray())
y_pred_test_lr = logistic_regression.predict(X_test.toarray())

# Evaluasi akurasi model Logistic Regression pada data pelatihan
accuracy_train_lr = accuracy_score(y_pred_train_lr, y_train)

# Evaluasi akurasi model Logistic Regression pada data uji
accuracy_test_lr = accuracy_score(y_pred_test_lr, y_test)

# Menampilkan akurasi
print('Logistic Regression - accuracy_train:', accuracy_train_lr)
print('Logistic Regression - accuracy_test:', accuracy_test_lr)
# Out:
# Logistic Regression - accuracy_train: 0.8761428571428571
# Logistic Regression - accuracy_test: 0.861

# %% [markdown]
# ### Pemodelan: Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Membuat objek model Decision Tree
decision_tree = DecisionTreeClassifier()

# Melatih model Decision Tree pada data pelatihan
decision_tree.fit(X_train.toarray(), y_train)

# Prediksi sentimen pada data pelatihan dan data uji
y_pred_train_dt = decision_tree.predict(X_train.toarray())
y_pred_test_dt = decision_tree.predict(X_test.toarray())

# Evaluasi akurasi model Decision Tree
accuracy_train_dt = accuracy_score(y_pred_train_dt, y_train)
accuracy_test_dt = accuracy_score(y_pred_test_dt, y_test)

# Menampilkan akurasi
print('Decision Tree - accuracy_train:', accuracy_train_dt)
print('Decision Tree - accuracy_test:', accuracy_test_dt)
# Out:
# Decision Tree - accuracy_train: 0.9987142857142857
# Decision Tree - accuracy_test: 0.774

# %% [markdown]
# ### Pemodelan: Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

# Membuat objek model Naive Bayes (Bernoulli Naive Bayes)
naive_bayes = BernoulliNB()

# Melatih model Naive Bayes pada data pelatihan
naive_bayes.fit(X_train.toarray(), y_train)

# Prediksi sentimen pada data pelatihan dan data uji
y_pred_train_nb = naive_bayes.predict(X_train.toarray())
y_pred_test_nb = naive_bayes.predict(X_test.toarray())

# Evaluasi akurasi model Naive Bayes
accuracy_train_nb = accuracy_score(y_pred_train_nb, y_train)
accuracy_test_nb = accuracy_score(y_pred_test_nb, y_test)

# Menampilkan akurasi
print('Naive Bayes - accuracy_train:', accuracy_train_nb)
print('Naive Bayes - accuracy_test:', accuracy_test_nb)
# Out:
# Naive Bayes - accuracy_train: 0.8338571428571429
# Naive Bayes - accuracy_test: 0.816

# %% [markdown]
# #### Melihat akurasi data test dari keempat model

# %%
results_df = pd.DataFrame({
    'Model': ['Naive Bayes', 'Random Forest', 'Logistic Regression', 'Decision Tree'],
    'Accuracy Train': [accuracy_train_nb, accuracy_train_rf, accuracy_train_lr, accuracy_train_dt],
    'Accuracy Test': [accuracy_test_nb, accuracy_test_rf, accuracy_test_lr, accuracy_test_dt]
})

accuracy_test_only = results_df[['Model', 'Accuracy Test']]
print(accuracy_test_only)
# Out:
#                  Model  Accuracy Test
# 0          Naive Bayes       0.816000
# 1        Random Forest       0.834333
# 2  Logistic Regression       0.861000
# 3        Decision Tree       0.774000

# %%
accuracy_test_sorted = accuracy_test_only.sort_values(by='Accuracy Test', ascending=False)
print(accuracy_test_sorted)
# Out:
#                  Model  Accuracy Test
# 2  Logistic Regression       0.861000
# 1        Random Forest       0.834333
# 0          Naive Bayes       0.816000
# 3        Decision Tree       0.774000

# %% [markdown]
# ### Memprediksi dengan logistic regression krn akurasinya paling tinggi

# %%
kalimat_baru = input("Masukkan kalimat baru: ")

kalimat_baru_cleaned = cleaningText(kalimat_baru)
kalimat_baru_casefolded = casefoldingText(kalimat_baru_cleaned)
kalimat_baru_slangfixed = fix_slangwords(kalimat_baru_casefolded)
kalimat_baru_tokenized = tokenizingText(kalimat_baru_slangfixed)
kalimat_baru_filtered = filteringText(kalimat_baru_tokenized)
kalimat_baru_final = toSentence(kalimat_baru_filtered)

X_kalimat_baru = tfidf.transform([kalimat_baru_final])

prediksi_sentimen = logistic_regression.predict(X_kalimat_baru)

if prediksi_sentimen[0] == 'positive':
    print("Sentimen kalimat baru adalah POSITIF.")
elif prediksi_sentimen[0] == 'negative':
    print("Sentimen kalimat baru adalah NEGATIF.")
else:
    print("Sentimen kalimat baru adalah NETRAL.")
# Out:
# Masukkan kalimat baru: perbaiki sistem bayarnya
# Sentimen kalimat baru adalah NEGATIF.

# %%
kalimat_baru = input("Masukkan kalimat baru: ")

kalimat_baru_cleaned = cleaningText(kalimat_baru)
kalimat_baru_casefolded = casefoldingText(kalimat_baru_cleaned)
kalimat_baru_slangfixed = fix_slangwords(kalimat_baru_casefolded)
kalimat_baru_tokenized = tokenizingText(kalimat_baru_slangfixed)
kalimat_baru_filtered = filteringText(kalimat_baru_tokenized)
kalimat_baru_final = toSentence(kalimat_baru_filtered)

X_kalimat_baru = tfidf.transform([kalimat_baru_final])

prediksi_sentimen = logistic_regression.predict(X_kalimat_baru)

if prediksi_sentimen[0] == 'positive':
    print("Sentimen kalimat baru adalah POSITIF.")
elif prediksi_sentimen[0] == 'negative':
    print("Sentimen kalimat baru adalah NEGATIF.")
else:
    print("Sentimen kalimat baru adalah NETRAL.")
# Out:
# Masukkan kalimat baru: sudah sangat membantu
# Sentimen kalimat baru adalah NETRAL.

# %%
kalimat_baru = input("Masukkan kalimat baru: ")

kalimat_baru_cleaned = cleaningText(kalimat_baru)
kalimat_baru_casefolded = casefoldingText(kalimat_baru_cleaned)
kalimat_baru_slangfixed = fix_slangwords(kalimat_baru_casefolded)
kalimat_baru_tokenized = tokenizingText(kalimat_baru_slangfixed)
kalimat_baru_filtered = filteringText(kalimat_baru_tokenized)
kalimat_baru_final = toSentence(kalimat_baru_filtered)

X_kalimat_baru = tfidf.transform([kalimat_baru_final])

prediksi_sentimen = logistic_regression.predict(X_kalimat_baru)

if prediksi_sentimen[0] == 'positive':
    print("Sentimen kalimat baru adalah POSITIF.")
elif prediksi_sentimen[0] == 'negative':
    print("Sentimen kalimat baru adalah NEGATIF.")
else:
    print("Sentimen kalimat baru adalah NETRAL.")
# Out:
# Masukkan kalimat baru: sangat mudah digunakan
# Sentimen kalimat baru adalah POSITIF.

# %%
import subprocess

installed_packages = subprocess.check_output(["pip", "freeze"]).decode("utf-8").split('\n')

desired_packages = {
    "Flask",
    "requests",
    "numpy",
    "pandas",
    "scikit-learn",
    "nltk",
    "Sastrawi",
    "matplotlib",
    "seaborn"
}

filtered_packages = [pkg for pkg in installed_packages if pkg.split('==')[0] in desired_packages]

with open('requirements.txt', 'w') as f:
    for pkg in filtered_packages:
        f.write(pkg + '\n')
